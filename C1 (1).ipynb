# %%
import matplotlib.pyplot as plt  

#Vai buscar o ficheiro "company_sales_data.csv" à sua localização
f = open('desktop/company_sales_data.csv')
df = pd.read_csv(f)

#Vai buscar dados às listas
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()

#Linha do gráfico
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')

#Nome do eixo x
plt.xlabel('Month number')
#Nome do eixo y
plt.ylabel('Profit in dollar')

#Valores do eixo x importados da lista "month_number"
plt.xticks(monthList)

#Titulo do gráfico
plt.title('Company profit per month')

#Valores do eixo y
plt.yticks([100000, 200000, 300000, 400000, 500000])

#Mostra o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt  

#Vai buscar o ficheiro "company_sales_data.csv" à sua localização
f = open('desktop/company_sales_data.csv')
df = pd.read_csv(f)

#Vai buscar dados às listas
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()

#Estilo da linha do gráfico
plt.plot(monthList, profitList, label = 'Profit data of last year', 
      color='r', marker='o', markerfacecolor='k', 
      linestyle='--', linewidth=3)
      
#Nome do eixo X
plt.xlabel('Número do mês') 

#Nome do eixo Y 
plt.ylabel('Número de unidades vendidas') 

#Localização da legenda
plt.legend(loc='lower right')

#Nome do gráfico
plt.title('Company Sales data of last year')

#Valores do eixo x importados da lista "month_number"
plt.xticks(monthList)

#Valores do eixo y
plt.yticks([100000, 200000, 300000, 400000, 500000])

#Mostra o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt  

#Vai buscar o ficheiro "company_sales_data.csv" à sua localização
f = open('desktop/company_sales_data.csv')
df = pd.read_csv(f)

#Vai buscar todos os dados que são necessários para o gráfico
monthList = df ['month_number'].tolist()
faceCremSalesData = df ['facecream'].tolist()
faceWashSalesData = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData = df ['bathingsoap'].tolist()
shampooSalesData = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

#Desenha a linha para cada um produtos e faz também a legenda
plt.plot(monthList, faceCremSalesData, label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)

#Nome do eixo X
plt.xlabel('Month Number')

#Nome do eixo Y 
plt.ylabel('Sales units in number')

#Localização da legenda
plt.legend(loc='upper left')

#Valores do eixo x importados da lista "month_number"
plt.xticks(monthList)

#Valores do eixo y
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])

#Nome do gráfico
plt.title('Sales data')

#Mostra o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt  

#Vai buscar o ficheiro "company_sales_data.csv" à sua localização
f = open('desktop/company_sales_data.csv')
df = pd.read_csv(f)

#Vai buscar dados à lista
monthList  = df ['month_number'].tolist()

#Nomeia cada fatia do gráfico e faz também a legenda
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']

#Vai buscar os dados necessários para realizar o gráfico
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]

#Desenha um circulo perfeito
plt.axis("equal")

#Vai busca os dados necessários e depois dá a percentagem e o nome de cada produto a cada fatia
plt.pie(salesData, labels=labels, autopct='%1.1f%%')

#Localização da legenda
plt.legend(loc='lower right')

#Nome do gráfico
plt.title('Sales data')

#Mostra o gráfico
plt.show()
